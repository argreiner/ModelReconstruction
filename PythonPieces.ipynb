# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as optim

# %%
# Recursive programming
def fibonacci(n):
    if n == 0: return 0
    if n == 1: return 1
    return fibonacci(n-1)+fibonacci(n-2)
# And now the factorial

# %%
# Root finding
def fun(x,*argv):
    a=argv
    return x - a*np.cos(x)

sol1 = optim.root(fun, x0 = 0,args=(2.))
sol2 = optim.root(fun, x0 = -2.,args=(3.))
print("root of f(x,2.): x =", sol1.x)
print("root of f(x,3.): x =", sol2.x)

# %%
# %matplotlib notebook
x=np.linspace(-3.,3.)
plt.plot(x,fun(x,2.))
plt.plot(x,fun(x,3.))
plt.plot(np.linspace(-3.5,3.5,10),np.zeros(10))

# %%
# Let's define the function 
def u(ai):
    x=np.linspace(0,1,101) 
    c=(np.sin(ai)+np.sinh(ai))*(np.cos(ai*x)-np.cosh(ai*x))-(np.cos(ai)+np.cosh(ai))*(np.sin(ai*x)-np.sinh(ai*x)) 
    umax=np.max(np.abs(c))
    return c/umax
#
# Open a new cell
#

# %%
# %matplotlib notebook 
a=[1.88,4.69,7.85,11.0] 
f1=u(a[0])
f2=u(a[1])
f3=u(a[2])
f4=u(a[3]) 
plt.plot(f1) 
plt.plot(f2) 
plt.plot(f3) 
plt.plot(f4) 
plt.plot(np.zeros(100))
plt.show()
plt.savefig('MyFigure.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f=np.zeros(100)
f[45:54]=1.
f[-1]=5
f[0]=3
dt=0.1

# %%
np.roll(f,1)-2*f+np.roll(f,-1)

# %%
f

# %%
# %matplotlib notebook
#Get the libraries
import numpy as np
import matplotlib.pyplot as plt
#
f=np.zeros(100) # Define the solution vector, 
f[45:55]=1.0 # set initial conditions ,
# choose Delta t
dt=.4 # that's a good choice
# dt = 0.6 # this starts to oscillate #dt=1. #thisblowsup
# The above must be at the first row or the cell
timesteps =1000 # number 
for i in np.arange(timesteps):
    fl=np.roll(f,1) 
    fr=np.roll(f,-1) 
    fc=f.copy() 
    f=f+(fl-2*fc+fr)*dt
#of timesteps
# loop
# shift right f
# shift left f
# copy in order not to overwrite # caluate one timestep forward
    if i%100 == 0: 
        plt.plot(f) # plot every 100. timestep 
        plt.savefig('myDifusion'+str(i)+'.png')
plt.show() # show the plots
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f=np.zeros(100) # Define the solution vector, 
f[45:55]=1.0 # set initial conditions ,

# %%
# %matplotlib notebook
plt.plot(f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f
# Out:
# array([0.05982058, 0.05997521, 0.06028392, 0.06074562, 0.06135866,
#        0.06212087, 0.06302952, 0.06408138, 0.06527267, 0.0665991 ,
#        0.0680559 , 0.06963779, 0.071339  , 0.07315333, 0.07507409,
#        0.07709421, 0.07920618, 0.08140211, 0.08367376, 0.08601254,
#        0.08840957, 0.09085567, 0.09334144, 0.09585724, 0.09839327,
#        0.10093959, 0.10348614, 0.10602282, 0.10853949, 0.11102603,
#        0.1134724 , 0.11586865, 0.11820498, 0.12047179, 0.12265971,
#        0.12475967, 0.12676289, 0.128661  , 0.13044599, 0.13211033,
#        0.13364697, 0.13504937, 0.13631153, 0.13742807, 0.13839419,
#        0.13920574, 0.13985922, 0.14035182, 0.14068141, 0.14084656,
#        0.14084656, 0.14068141, 0.14035182, 0.13985922, 0.13920574,
#        0.13839419, 0.13742807, 0.13631153, 0.13504937, 0.13364697,
#        0.13211033, 0.13044599, 0.128661  , 0.12676289, 0.12475967,
#        0.12265971, 0.12047179, 0.11820498, 0.11586865, 0.1134724 ,
# ...

# %%
print('myDifusion'+str(i)+'.png')
# Out:
# myDifusion999.png
